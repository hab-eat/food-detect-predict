# %%
# !nvidia-smi
# Out:
# Fri Nov 22 08:02:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 41.7 MB/s eta 0:00:00
# ...

# %%
########################################## 음식분류 - Google One 계정

#전체 구조 생성
# !mkdir -p /content/food/train/labels
# !mkdir -p /content/food/val/labels

# !mkdir -p /content/food/train/images
# !mkdir -p /content/food/val/images

#라벨부터 준비
# !unzip /content/drive/MyDrive/foodOrigin/train/label_food_train.zip -d /content/food/train/labels
# !unzip /content/drive/MyDrive/foodOrigin/val/label_food_val.zip -d /content/food/val/labels



#라벨 한쪽만 사용
#txt - YOLO 형식 사용
# !rm -rf /content/food/train/labels/xml
# !rm -rf /content/food/val/labels/xml
#xml - VOC 형식 사용
#!rm -rf /content/food/val/labels/txt
#!rm -rf /content/food/train/labels/txt
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161067160018534_1.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161067550521670_1.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161068149280712_1.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161068161076517_1.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161068164550073_0.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161068174256527_0.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161070871769204_0.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161070880376919_0.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161071483558459_0.xml
#   inflating: /content/food/val/labels/xml/14012001/14_142_14012001_161071835814314_1.xml
# ...

# %%
#yaml 파일 준비

# !cp /content/drive/MyDrive/foodOrigin/train1.yaml /content/food/

#매 트레이닝 시마다 업데이트 반드시 할 것

# %%
#드라이브 내 데이터셋 코랩으로 unzip
#-d /content/food/train/images
#-d /content/food/val/images

# !unzip /content/drive/MyDrive/foodOrigin/train/[원천]음식분류_TRAIN_001.zip -d /content/food/train/images
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234133526994_1.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234135659340_1.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234146846575_0.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234146846575_1.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234148553741_1.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234150785947_0.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234150785947_1.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234154889133_0.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234154889133_1.jpg
#   inflating: /content/food/train/images/train/01012004/01_012_01012004_161234157270117_0.jpg
# ...

# %%
#Validation 파일 - 잘라둔 파일 사용
# !cp -r /content/drive/MyDrive/foodOrigin/val/val01/* /content/food/val/images

# %%
#트레이닝 단계
#매 트레이닝 시마다 yaml파일 수정 후 변경
from ultralytics import YOLO

model = YOLO("yolo11l.pt")
results = model.train(data="/content/food/train1.yaml", epochs=15, imgsz=640, save=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 49.0M/49.0M [00:01<00:00, 32.0MB/s]
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
